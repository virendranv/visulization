# %% [markdown]
# # Matplotlib

# %% [markdown]
# python 2D plotting library which produces publication quality figures in a variety of hardcopy formats a set of functionalities similar to those of MATLAB
#
# line plots, scatter plots, barcharts, histograms, pie charts etc.
#
# relatively low-level; some effort needed to create advanced visualization

# %% [markdown]
# # Line Chart

# %%
import matplotlib.pyplot as plt
import numpy as np
x = [2, 4, 6]
y = [1, 3, 5]
plt.plot(x, y)
plt.show()

# %%
year = [1960, 1970, 1980, 1990, 2000, 2010]
pop_us = [44.91, 58.09, 78.07, 107.7, 138.5, 170.6]
pop_india = [449.48, 553.57, 696.783, 870.133, 1000.4, 1309.1]
plt.plot(year, pop_us, color='g',label='US')
plt.plot(year, pop_india, color='orange',label='india')
plt.xlabel('Countries')
plt.ylabel('Population in million')
plt.title(' India _ US Population till 2010')
plt.legend()
plt.show()

# %% [markdown]
# # Subplot chart

# %%
fig,(ax1,ax2)=plt.subplots(2,figsize = (7,7))
ax1.plot(x,y)
sns.boxplot(data=tip,ax=ax1)
ax1.plot(x,y)
ax2.plot(x,y)
x=np.linspace(0,5,11)
y=x**2
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-7b47620eacd3> in <module>()
#       1 fig,(ax1,ax2)=plt.subplots(2,figsize = (7,7))
#       2 ax1.plot(x,y)
# ----> 3 sns.boxplot(data=tip,ax=ax1)
#       4 ax1.plot(x,y)
#       5 ax2.plot(x,y)
#
# NameError: name 'sns' is not defined

# %% [markdown]
# # Bar chart

# %%
import numpy as np
import matplotlib.pyplot as plt
 
# Make a fake dataset:
height = [3, 12, 5, 18, 45]
bars = ('A', 'B', 'C', 'D', 'E')
 
# Create bars
plt.bar(bars, height)
 

# Show graphic
plt.show()

# %% [markdown]
# # pie chart

# %%
import matplotlib.pyplot as plt
 
import matplotlib.pyplot as plt
 
# Data to plot
labels = ['Python', 'C++', 'Ruby', 'Java']
sizes = [215, 130, 245, 210]
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
explode = (0.1, 0, 0, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=True, startangle=140)
 
plt.axis('equal')
plt.show()

# %% [markdown]
# # Scatter Plot

# %% [markdown]
# A Scatter (XY) Plot has points that show the relationship between two sets of data

# %%
x = [1,5,6,9]
y = [8,9,1,2]
plt.scatter(x,y)

# %% [markdown]
# # Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np

gaussian_numbers = np.random.randn(1000)
plt.hist(gaussian_numbers)
plt.title("Gaussian Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
# Out:
# Text(0,0.5,'Frequency')

# %% [markdown]
# # Seaborn

# %% [markdown]
# Graphics to explore the data
#
# Seaborn package is built on matplotlib but provides high level interface for drawing attractive statistical graphics, similar to ggplot2 library in R. It specifically targets statistical data visualization
#
# To show graphs within Python notebook include inline directive:
#
#
#     %matplotlib inline

# %% [markdown]
#  Seaborn is a statistical plotting library
# It has beautiful default styles
# It is also  designed to work very well with pandas DataFrame
#
# Load Data:
#
#     Import matplotlib.pyplot as plt
#
#     %matplotlib inline
#
#     Import seaborn as sns
#
#     tip=sns.load_dataset(‘tips)

# %% [markdown]
# Graphs:
#
#                Description
#
# distplot   -   histogram
# barplot    -   estimate of central tendency for a numeric variable
# violinplot -   similar to boxplot,also shows the probability density of the data
# jointplot  -   scatterplot
# lmplot     -   Regression plot
# pairplot   -   pairplot
# boxplot    -   boxplot
# swarmplot  - categorical scatterplot
# factorplot - General categorical plot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

tip=sns.load_dataset('tips')

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Distribution Plot

# %% [markdown]
# Distribution plot will gives univariate
#
# In histogram on top of that line is known as Kernal Density Function(KDE)

# %%
sns.distplot(tip['total_bill'],kde = True)

# %% [markdown]
# # Joint Plot

# %% [markdown]
# Joint plot is bivariate .we can validate how the two variables distributed

# %%
sns.jointplot(x='total_bill',y='tip',data = tip)

# %% [markdown]
# # Pair Plot

# %% [markdown]
# Pair plot will plot a diagram all against the all possible combination of all numerical values. This  is most important plots
#
# We will work on this plot through  out our ML

# %%
sns.pairplot(data=tip)

# %% [markdown]
# # Rug plot

# %% [markdown]
# Distplot will shows the bins .Rugplot will shows the it’s points of the line.  Rest  all are same

# %%
sns.rugplot(tip['total_bill'])

# %% [markdown]
# # Bar plot

# %%
sns.barplot(x='sex',y='total_bill',data=tip)

# %% [markdown]
# # Count plot

# %%
sns.countplot(x='sex',data=tip)

# %% [markdown]
# # Box plot

# %% [markdown]
# Box plot shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution,except for points that are determined to be ‘outliers’

# %%
sns.boxplot(data=tip)

# %% [markdown]
# # Violinplot

# %% [markdown]
# A violinplot plays a similar role as aboxplot and whiskerplot it shows the distribution of  dataset

# %%
sns.violinplot(data=tip)

# %% [markdown]
# # strip plot

# %%
sns.stripplot(x='day',y='total_bill',data=tip)

# %% [markdown]
# # Swarm plot

# %%
sns.swarmplot(data=tip,x='sex',y='total_bill')

# %% [markdown]
# # Factorplot

# %% [markdown]
# Factor plot is the most general form of a categorical and numerical plot.it can take in a kind parameter to adjust the plot type

# %%
sns.factorplot(data=tip,x='day',y='total_bill')

# %% [markdown]
# # Heatmap

# %%
sns.heatmap(tip.corr())

# %% [markdown]
# # lmplot

# %%
sns.lmplot(x='tip',y='total_bill',data =tip)

# %% [markdown]
# # CUFFLINKS

# %% [markdown]
# Cufflinks like web  based reports
# It gives high intensive picture/graphs
#
# Installation:
#
#     Cufflinks Not available in condas
#
#     Available in pip
# 		pip install plotly
# 		pip install cufflinks

# %% [markdown]
# # Import and setup

# %% [markdown]
#         import numpy as np
# 		import pandas as pd
# 		import matplotlib.pyplot as plt
# 		%matplotlib inline
# 		import plotly as pl
# 		import  cufflinks as cf
# 		cf.go_offline()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly as pl
import  cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# # Scatter plot

# %%
tip.iplot(kind='scatter',x='size',y='total_bill')
# Out:
# <div>
#
#
#             <div id="d6b90f70-cae4-48c2-bfaa-32b745e48498" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("d6b90f70-cae4-48c2-bfaa-32b745e48498")) {
#                     Plotly.newPlot(
#                         'd6b90f70-cae4-48c2-bfaa-32b745e48498',
# ...

# %% [markdown]
# # Bar plot

# %%
tip.iplot(kind = 'bar',x='day',y='total_bill')
# Out:
# <div>
#
#
#             <div id="5cad9e3e-6827-430e-ac42-54b8dcb4fb39" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("5cad9e3e-6827-430e-ac42-54b8dcb4fb39")) {
#                     Plotly.newPlot(
#                         '5cad9e3e-6827-430e-ac42-54b8dcb4fb39',
# ...

# %% [markdown]
# # Count plot

# %%
tip.count().iplot(kind='bar')
# Out:
# <div>
#
#
#             <div id="f5ea8596-fb3f-4684-89af-9cd03ee6eb11" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("f5ea8596-fb3f-4684-89af-9cd03ee6eb11")) {
#                     Plotly.newPlot(
#                         'f5ea8596-fb3f-4684-89af-9cd03ee6eb11',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "None", "orientation": "v", "text": "", "type": "bar", "uid": "4036a554-1b54-447f-94a7-b08bb17d6e4f", "x": ["total_bill", "tip", "sex", "smoker", "day", "time", "size"], "y": [244, 244, 244, 244, 244, 244, 244]}],
# ...

# %% [markdown]
# # Box plot

# %%
tip.iplot(kind='box')
# Out:
# <div>
#
#
#             <div id="c7b4b5d3-ecc5-43b3-b5dc-f1069de25ede" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c7b4b5d3-ecc5-43b3-b5dc-f1069de25ede")) {
#                     Plotly.newPlot(
#                         'c7b4b5d3-ecc5-43b3-b5dc-f1069de25ede',
# ...

# %% [markdown]
# # 3-D  Surface

# %%
df1=pd.DataFrame({'x':[1,2,3,4,5],
                   'y':[10,20,80,20,10],
                     'z':[5,4,3,2,1]})

# %%
df1.iplot(kind='surface',colorscale='rdylbu')
# Out:
# <div>
#
#
#             <div id="be5151cb-ee48-4055-b759-de43596b8051" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("be5151cb-ee48-4055-b759-de43596b8051")) {
#                     Plotly.newPlot(
#                         'be5151cb-ee48-4055-b759-de43596b8051',
# ...

# %% [markdown]
# # Spread  (surface)

# %%
df1[['y','z']].iplot(kind='spread')
# Out:
# <div>
#
#
#             <div id="77c5788a-7738-4272-9ba2-0e30bd0d9c94" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("77c5788a-7738-4272-9ba2-0e30bd0d9c94")) {
#                     Plotly.newPlot(
#                         '77c5788a-7738-4272-9ba2-0e30bd0d9c94',
# ...

# %% [markdown]
# # Histogram

# %%
tip['total_bill'].iplot(kind='hist',)
# Out:
# <div>
#
#
#             <div id="4502b7d6-8c54-43c2-a6a1-d80e58facad2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("4502b7d6-8c54-43c2-a6a1-d80e58facad2")) {
#                     Plotly.newPlot(
#                         '4502b7d6-8c54-43c2-a6a1-d80e58facad2',
# ...

# %% [markdown]
# # Bubble plot

# %%
df1.iplot(kind='bubble',x='x',y='y',size='z')
# Out:
# <div>
#
#
#             <div id="19809f86-9fcf-4f69-84ec-f71175493f62" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("19809f86-9fcf-4f69-84ec-f71175493f62")) {
#                     Plotly.newPlot(
#                         '19809f86-9fcf-4f69-84ec-f71175493f62',
# ...
